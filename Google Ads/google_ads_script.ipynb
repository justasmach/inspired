# %%
import sys, os, os.path
base, tail = os.path.split(os.getcwd())
sys.path.append(base)
from helper_functions import *

def google_ads(client, customer_id, page_size, df_conf_req, period):
    ga_service = client.get_service('GoogleAdsService', version='v2')
    channel_types = client.get_type('AdvertisingChannelTypeEnum')
    
    # create a list containing dimensions
    dim_str = ''
    dim_lst = []
    for index, row in df_conf_req.iterrows():
        dim_lst.append(row['dimensions'])
        dim_str = dim_str + row['dimensions'] + ', '
    dim_str = dim_str[:-2]
    
    print('Calling Google Ads API...')
    # make the call to Google Ads using compiled parameters 
    print(period)
    query = f"SELECT {dim_str} FROM campaign WHERE {period}"

    response = ga_service.search(customer_id, query, page_size=page_size)

    df_response = pd.DataFrame()
    row_count = 0
    
    # iterate over response and add everything to a pandas dataframe
    try:
        for index, row in enumerate(response):
            row_count = index
            new_dim_lst = []
            new_dim_dtype_lst = []
            
            
            # create a list for dimension data types
            for dim in dim_lst:
                if 'int' in str(type(eval('row.' + dim))).lower():
                    new_dim_dtype_lst.append('int')
                elif 'double' in str(type(eval('row.' + dim))).lower():
                    new_dim_dtype_lst.append('float')
                else:
                    new_dim_dtype_lst.append('string')
                
                if 'google' in str(type(eval('row.' + dim))):
                    new_dim_lst.append('row.' + dim + '.value')
                else:
                    new_dim_lst.append('row.' + dim)
            
            # iterate over dimensions of a single row
            for idx, new_dim in enumerate(new_dim_lst):
                if dim_lst[idx] == 'campaign.advertising_channel_type':
                    df_response.loc[index, dim_lst[idx]] = str(channel_types.AdvertisingChannelType.Name(eval('row.' + dim_lst[idx])))
                    df_response[dim_lst[idx]] = df_response[dim_lst[idx]].astype('object')
                elif dim_lst[idx] == 'metrics.cost_micros':                 
                    df_response.loc[index, dim_lst[idx]] = float(float(eval(new_dim)) / 100000)
                    df_response[dim_lst[idx]] = df_response[dim_lst[idx]].astype('float64')
                elif new_dim_dtype_lst[idx] == 'int':
                    df_response.loc[index, dim_lst[idx]] = int(eval(new_dim))
                    df_response[dim_lst[idx]] = df_response[dim_lst[idx]].astype('int64')
                elif new_dim_dtype_lst[idx] == 'float':
                    df_response.loc[index, dim_lst[idx]] = float(eval(new_dim))
                    df_response[dim_lst[idx]] = df_response[dim_lst[idx]].astype('float64')
                else:
                    df_response.loc[index, dim_lst[idx]] = str(eval(new_dim))
                    df_response[dim_lst[idx]] = df_response[dim_lst[idx]].astype('object')
                
    # return error messages if exception
    except google.ads.google_ads.errors.GoogleAdsException as ex:
        print('Request with ID "%s" failed with status "%s" and includes the '
              'following errors:' % (ex.request_id, ex.error.code().name))
        for error in ex.failure.errors:
            print('\tError with message "%s".' % error.message)
            if error.location:
                for field_path_element in error.location.field_path_elements:
                    print('\t\tOn field: %s' % field_path_element.field_name)
        sys.exit(1)
    print(str(row_count + 1) + ' row(s) received')
    return df_response
                     
def start():
    # If the google-ads.yaml file is present in home dir, GoogleAdsClient will read the configuration.  
    _DEFAULT_PAGE_SIZE = 500
    print('Starting...')
    do_drop = False
    try:
        # read configuration from excel
        google_ads_client = (google.ads.google_ads.client.GoogleAdsClient.load_from_storage())
        df_conf_base = pd.read_excel('google_ads_conf_1.xlsx', sheet_name='base', header=0)
        df_conf_req = pd.read_excel('google_ads_conf_1.xlsx', sheet_name='parameters', header=0)
        if pd.isna(df_conf_base['customer_id'].iloc[0]):
            raise KeyError('No base data provided (customer_id(s))')
        if pd.isna(df_conf_req['period'].iloc[0]):
            raise KeyError('Period is missing')    
        for index, row in df_conf_req.iterrows():
            if pd.isna(row['dimensions']):
                raise KeyError('One or more dimensions missing')
        period = str(df_conf_req.iat[0,1])
        per_format = "segments.date >= 'x1' AND segments.date <= 'x2'"
        period = upd_last_90(period, per_format)
    except(NameError, XLRDError, KeyError) as error:
        print('Error while reading configuration file(s)')
        print(error)
        sys.exit(1)
    
    # iterate over customers
    for index, row in df_conf_base.iterrows():              
        try:
            customer_id = str(int(row['customer_id']))
            #customer_id = str(df_conf_base.iat[0,0])
            print('Customer ID: ' + customer_id)
        except(KeyError) as error:
            print('Could not read column')
            print(error)
            sys.exit(1)
        
        # call defined methods
        df_response = google_ads(google_ads_client, customer_id, _DEFAULT_PAGE_SIZE, df_conf_req, period)
    
        t_name = 'google_ads_new'
        pk_name = 'google_ads_new_pk'
        pk_lst = ['campaign_id', 'segments_date']
        page_size = 100000
        src_col_name = 'campaign_name'
        is_pln_df = True
        
        if not df_response.empty:
            postgre_write_main(df_response, t_name, pk_name, pk_lst, do_drop, page_size, src_col_name, is_pln_df)
            do_drop = False
        print('Success')
    return df_response
        
try:
    start()
except(KeyError) as error:
    err_txt = 'A key error occurred:'
    print(err_txt)
    print('')
    print(error)
    compose_mail(err_txt, err_txt)
    send_mail()
# Out:
# Starting...
# Customer ID: 1786196469
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 360 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8855085244
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3906213713
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 4116257830
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 7082289274
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 7932398349
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 853 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1912380076
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 2012 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5836330057
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 17 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2802410968
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8989496691
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6847677968
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 224 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5049295410
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3838905309
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 48 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6644034580
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 93 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8865946584
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 7032668329
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 193 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9019660744
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 107 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4189715768
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3179089166
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2564244835
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2455551688
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 1631886244
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8966876519
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3501386700
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 362 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1399684617
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 184 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9505402795
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 160 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8501129397
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2966781292
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 4 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9453548164
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 180 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5218346619
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 43 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5253771656
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1361 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1355732244
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 779 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4993626450
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2293810399
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2121824386
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8886988449
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 7320394900
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5552112694
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 28 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 7613707069
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 358 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9107304757
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 90 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2572041162
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8991691654
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 758 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6036021048
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 103 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9202854280
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 523 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 7250766737
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 177 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4760817727
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1668 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 3953376711
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5470129919
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 2 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 7977147931
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 66 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9273295723
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3900715376
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 7370625770
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 80 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5949240729
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6531866003
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3031688474
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5501391027
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8551141829
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 538 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5570631450
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5374215103
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 307 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8542018648
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2740032828
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 805 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8595445045
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 316 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4507580886
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 221 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8047193422
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 994 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2174442438
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 630 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6309997154
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 65 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4629984059
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 136 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 7630499500
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 4554668239
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 1211567748
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5663920045
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5058100548
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2118195690
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 85 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9902757790
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5301705439
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 178 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8001048650
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 213 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8778901500
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 178 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1313353523
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 270 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4353554621
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 270 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 3347524099
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 268 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6359113960
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 9816119311
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 151 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2550709954
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 131 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9684978068
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 270 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 3615594235
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8107920354
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1343 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5227905793
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2881869686
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 404 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1829159374
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6683746486
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 891 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8893844181
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2163066616
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1039 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4684238924
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 360 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5296269500
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 28 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4694184580
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 1141829917
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6085239095
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 195 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6246763782
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2293236378
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2372776409
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 165 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 3356851548
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 242 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4924921305
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 66 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 3682724795
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 749 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5480868364
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 43 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1486110296
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 7735624533
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 118 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6307018164
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 3 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4330581660
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 1792909731
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5867033340
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 18 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8166744825
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2914415013
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 3493791842
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 69 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4467983778
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 855 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 6203646753
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1141 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 4478215933
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 2897570192
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6121944599
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6462737209
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 5200959954
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 9969694495
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 157 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9755095172
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 165 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2154447239
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6710829460
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 348 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 3003108476
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8525372437
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 4317340882
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 270 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 8890849768
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 3247 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5757428131
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 4069904035
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 9482213522
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 197 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5358571337
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 398 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 1171521125
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 4404516495
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 348 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2122508100
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 6769481760
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 9550717003
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 1 row(s) received
# Success
# Customer ID: 8906888130
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 939 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 2922163142
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 40 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 5031641744
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 24 row(s) received
# Database connection closed.
#
# Success
# Customer ID: 9948547912
# Calling Google Ads API...
# segments.date >= '2019-09-06' AND segments.date <= '2019-12-04'
# 83 row(s) received
# Database connection closed.
#
# Success
